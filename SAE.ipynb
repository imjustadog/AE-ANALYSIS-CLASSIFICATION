# %%
from __future__ import division, print_function, absolute_import

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import glob
import numpy as np
import os

# %pylab inline

image_width=20

pwd = os.getcwd()
tfrecord_file_path = pwd + "/AE_input_knock_ch1.tfrecord"
filename_queue = tf.train.string_input_producer(
                              tf.train.match_filenames_once(tfrecord_file_path),
                              shuffle=True, num_epochs=None)

reader = tf.TFRecordReader()
_, serialized_example = reader.read(filename_queue)
features = tf.parse_single_example(serialized_example,
                                       features={'data': tf.FixedLenFeature([], tf.string)}) 
img = tf.decode_raw(features['data'], tf.uint8)
img = tf.image.convert_image_dtype(img,tf.float32)
img = tf.reshape(img, [image_width * image_width])
input_batch = tf.train.shuffle_batch([img],batch_size=20,capacity=500,min_after_dequeue=250,num_threads=4)

# Training Parameters
learning_rate = 0.001
num_steps = 100000
display_step = 1000

# Network Parameters
num_hidden_1 = 64 # 1st layer num features
num_input = image_width * image_width

X = tf.placeholder("float", [None, num_input],name='input_x')

encoder_h1=tf.Variable(tf.random_normal([num_input, num_hidden_1]))
decoder_h1=tf.transpose(encoder_h1)

biases = {
    'encoder_b1': tf.Variable(tf.random_normal([num_hidden_1])),
    'decoder_b1': tf.Variable(tf.random_normal([num_input])),
}

# Building the encoder
def encoder(x):
    # Encoder Hidden layer with sigmoid activation #1
    layer_1 = tf.nn.sigmoid(tf.add(tf.matmul(x, encoder_h1),
                                   biases['encoder_b1']))
    return layer_1


# Building the decoder
def decoder(x):
    # Decoder Hidden layer with sigmoid activation #1
    layer_1 = tf.nn.sigmoid(tf.add(tf.matmul(x, decoder_h1),
                                   biases['decoder_b1']))
    return layer_1

def cosine(a,b):
    a_norm = tf.sqrt(tf.reduce_sum(tf.pow(a,2)))
    b_norm = tf.sqrt(tf.reduce_sum(tf.pow(b,2)))
    a_b = tf.reduce_sum(tf.multiply(a,b))
    cosin = tf.divide(a_b,tf.multiply(a_norm,b_norm))
    return cosin

def kl_divergence(p, p_hat): #对所有x的每个h取平均作为phat，最终所有h相加求和
    return tf.reduce_sum(p * tf.log(p)
                            - p * tf.log(tf.clip_by_value(p_hat, 1e-8, tf.reduce_max(p_hat)))
                            + (1 - p) * tf.log(1-p)
                            - (1 - p) * tf.log(tf.clip_by_value(1-p_hat, 1e-8, tf.reduce_max(1-p_hat))))

# Construct model
encoder_op = encoder(X)
decoder_op = decoder(encoder_op)

# Prediction
y_pred = decoder_op
# Targets (Labels) are the input data.
y_true = X

# Define loss and optimizer, minimize the squared error

#loss = tf.reduce_sum(tf.pow(y_true - y_pred, 2))
sparsity_level = 0.001
loss = tf.reduce_sum(tf.pow(tf.subtract(y_true, y_pred), 2.0))+kl_divergence(sparsity_level, encoder_op)
optimizer = tf.train.AdamOptimizer(learning_rate).minimize(loss)

#loss = tf.reduce_sum(tf.subtract(tf.constant(1.0),cosine(y_true,y_pred)))
#optimizer = tf.train.RMSPropOptimizer(learning_rate).minimize(loss)

saver = tf.train.Saver()
tf.add_to_collection('output_y', encoder_op)
tf.add_to_collection('output_y', decoder_op)
#tf.add_to_collection('output_y', loss)

with tf.Session() as sess:
    
    tf.local_variables_initializer().run()
    tf.global_variables_initializer().run()
    coord = tf.train.Coordinator()
    thread = tf.train.start_queue_runners(sess=sess,coord=coord)
    
    result = []
    for i in range(1,num_steps+1):
        _, l, h = sess.run([optimizer, loss, encoder_op],feed_dict={X: input_batch.eval()})
        result.append(l)
        if i % display_step == 0 or i == 1:
            print('Step %i: Minibatch Loss: %f' % (i, l))
            
    saver.save(sess,'saver/SAE/SAE')
    
    coord.request_stop()
    coord.join(thread)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/input.py:187: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/input.py:187: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From <ipython-input-1-e93905489335>:105: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# Step 1: Minibatch Loss: 5229.454102
# Step 1000: Minibatch Loss: 339.697571
# Step 2000: Minibatch Loss: 170.056595
# Step 3000: Minibatch Loss: 108.160156
# Step 4000: Minibatch Loss: 93.871391
# Step 5000: Minibatch Loss: 63.079762
# Step 6000: Minibatch Loss: 62.357124
# Step 7000: Minibatch Loss: 54.175217
# Step 8000: Minibatch Loss: 52.048775
# Step 9000: Minibatch Loss: 63.534500
# Step 10000: Minibatch Loss: 57.492634
# Step 11000: Minibatch Loss: 53.652481
# Step 12000: Minibatch Loss: 60.647377
# Step 13000: Minibatch Loss: 50.072369
# Step 14000: Minibatch Loss: 50.055687
# Step 15000: Minibatch Loss: 60.789169
# Step 16000: Minibatch Loss: 64.913345
# Step 17000: Minibatch Loss: 46.819717
# Step 18000: Minibatch Loss: 53.957058
# Step 19000: Minibatch Loss: 51.981781
# Step 20000: Minibatch Loss: 57.955044
# Step 21000: Minibatch Loss: 51.718861
# Step 22000: Minibatch Loss: 73.668358
# Step 23000: Minibatch Loss: 48.969879
# Step 24000: Minibatch Loss: 58.301842
# Step 25000: Minibatch Loss: 47.092575
# Step 26000: Minibatch Loss: 45.368999
# Step 27000: Minibatch Loss: 51.862705
# Step 28000: Minibatch Loss: 58.857643
# Step 29000: Minibatch Loss: 46.395172
# Step 30000: Minibatch Loss: 42.219261
# Step 31000: Minibatch Loss: 51.481445
# Step 32000: Minibatch Loss: 55.044327
# Step 33000: Minibatch Loss: 53.276867
# Step 34000: Minibatch Loss: 59.000080
# Step 35000: Minibatch Loss: 44.645088
# Step 36000: Minibatch Loss: 45.487995
# Step 37000: Minibatch Loss: 71.705086
# Step 38000: Minibatch Loss: 53.796791
# Step 39000: Minibatch Loss: 44.519081
# Step 40000: Minibatch Loss: 40.720203
# Step 41000: Minibatch Loss: 53.091869
# Step 42000: Minibatch Loss: 53.901123
# Step 43000: Minibatch Loss: 58.383301
# Step 44000: Minibatch Loss: 48.513458
# Step 45000: Minibatch Loss: 42.327496
# Step 46000: Minibatch Loss: 70.115753
# Step 47000: Minibatch Loss: 51.449509
# Step 48000: Minibatch Loss: 48.381462
# Step 49000: Minibatch Loss: 48.592667
# Step 50000: Minibatch Loss: 46.540302
# Step 51000: Minibatch Loss: 49.732388
# Step 52000: Minibatch Loss: 53.178703
# Step 53000: Minibatch Loss: 60.769394
# Step 54000: Minibatch Loss: 45.352074
# Step 55000: Minibatch Loss: 55.147758
# Step 56000: Minibatch Loss: 70.188889
# Step 57000: Minibatch Loss: 53.166779
# Step 58000: Minibatch Loss: 48.413864
# Step 59000: Minibatch Loss: 45.852383
# Step 60000: Minibatch Loss: 41.599930
# Step 61000: Minibatch Loss: 54.667480
# Step 62000: Minibatch Loss: 46.116615
# Step 63000: Minibatch Loss: 60.383743
# Step 64000: Minibatch Loss: 38.958309
# Step 65000: Minibatch Loss: 41.069149
# Step 66000: Minibatch Loss: 51.616158
# Step 67000: Minibatch Loss: 36.520180
# Step 68000: Minibatch Loss: 48.176529
# Step 69000: Minibatch Loss: 51.954506
# Step 70000: Minibatch Loss: 46.319218
# Step 71000: Minibatch Loss: 51.099060
# Step 72000: Minibatch Loss: 49.524651
# Step 73000: Minibatch Loss: 54.063602
# Step 74000: Minibatch Loss: 65.454025
# Step 75000: Minibatch Loss: 39.524536
# Step 76000: Minibatch Loss: 45.092560
# Step 77000: Minibatch Loss: 47.974209
# Step 78000: Minibatch Loss: 41.036758
# Step 79000: Minibatch Loss: 44.801460
# Step 80000: Minibatch Loss: 39.240467
# Step 81000: Minibatch Loss: 49.250000
# Step 82000: Minibatch Loss: 59.645630
# Step 83000: Minibatch Loss: 50.016205
# Step 84000: Minibatch Loss: 48.425209
# Step 85000: Minibatch Loss: 46.393799
# Step 86000: Minibatch Loss: 55.836330
# Step 87000: Minibatch Loss: 51.345741
# Step 88000: Minibatch Loss: 51.352627
# Step 89000: Minibatch Loss: 38.601723
# Step 90000: Minibatch Loss: 48.911789
# Step 91000: Minibatch Loss: 46.256638
# Step 92000: Minibatch Loss: 46.287029
# Step 93000: Minibatch Loss: 49.096527
# Step 94000: Minibatch Loss: 54.477478
# Step 95000: Minibatch Loss: 61.677254
# Step 96000: Minibatch Loss: 40.790344
# Step 97000: Minibatch Loss: 50.899731
# Step 98000: Minibatch Loss: 39.979202
# Step 99000: Minibatch Loss: 62.338867
# Step 100000: Minibatch Loss: 47.689316
